# %%
import pandas as pd

interest_by_region_df = pd.read_csv("interest_by_region_df_keyword_only.csv")
interest_df = pd.read_csv("interest_df_keyword_only.csv")

# %%
interest_df.head()
# Out:
#          date  알러지  대상포진  수족구병  장염  식중독   감기  인플루엔자  동상
# 0  2019-01-01    0     0   0.0  85  NaN   90    0.0  76
# 1  2019-01-02    0    54   0.0  76  NaN  100    0.0   0
# 2  2019-01-03   77    52   0.0   0  NaN   79    0.0  79
# 3  2019-01-04    0    43   0.0  86  NaN   80    0.0   0
# 4  2019-01-05    0    66   0.0   0  NaN   82    0.0   0

# %%
interest_by_region_df.head()
# Out:
#    Unnamed: 0 geoName geoCode  알러지     date  대상포진  수족구병   장염  식중독  감기  인플루엔자  \
# 0           0     강원도   KR-42    0  2019-01   100     0  100  100  78    100
# 1           1     경기도   KR-41   25  2019-01    48     0   55   18  59     67
# 2           2    경상남도   KR-48    0  2019-01     0     0   48    0  74     60
# 3           3    경상북도   KR-47    0  2019-01    78     0   59    0  48     54
# 4           4   광주광역시   KR-29    0  2019-01    96     0   89    0  82     91
#
#     동상
# 0    0
# 1   42
# 2    0
# 3   64
# 4  100

# %%
interest_df.isnull().sum()
# Out:
# date        0
# 알러지         0
# 대상포진        0
# 수족구병     1552
# 장염          0
# 식중독       151
# 감기          0
# 인플루엔자     667
# 동상          0
# dtype: int64

# %%
interest_by_region_df.isnull().sum()
# Out:
# Unnamed: 0    0
# geoName       0
# geoCode       0
# 알러지           0
# date          0
# 대상포진          0
# 수족구병          0
# 장염            0
# 식중독           0
# 감기            0
# 인플루엔자         0
# 동상            0
# dtype: int64

# %%
interest_keywords_df = pd.concat(interest_keywords_df_list, axis=1)
interest_keywords_by_region_df = pd.concat(interest_keywords_by_region_df_list, axis=1)
interest_keywords_by_region_df = interest_keywords_by_region_df.loc[:, ~interest_keywords_by_region_df.columns.duplicated()]

# %%
interest_keywords_df

# %%
interest_keywords_df.info()

# %%
interest_keywords_by_region_df

# %%
interest_keywords_by_region_df.info()

# %% [markdown]
# MySql 8.0 이상 버전
# `pip install mysql-connector-python`
#
# 하위 버전
# `pip install mysql.connector`

# %%
# %pip install mysql-connector-python
# Out:
# ...
#   Using cached mysql_connector_python-9.1.0-cp310-cp310-macosx_13_0_arm64.whl.metadata (6.0 kB)
# Using cached mysql_connector_python-9.1.0-cp310-cp310-macosx_13_0_arm64.whl (15.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.getcwd()
# Out:
# '/Users/yonmilk/git/eda-repo-4'

# %%
import sys
sys.path
# Out:
# ['/opt/homebrew/anaconda3/envs/data_project_env/lib/python310.zip',
#  '/opt/homebrew/anaconda3/envs/data_project_env/lib/python3.10',
#  '/opt/homebrew/anaconda3/envs/data_project_env/lib/python3.10/lib-dynload',
#  '',
#  '/opt/homebrew/anaconda3/envs/data_project_env/lib/python3.10/site-packages',
#  '/opt/homebrew/anaconda3/envs/data_project_env/lib/python3.10/site-packages/setuptools/_vendor']

# %%
sys.path.append("/")

# %%
import os
from dotenv import load_dotenv

# .env 파일 로드
load_dotenv()

# 환경 변수 읽기
DB_HOST = os.getenv("DB_HOST")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_NAME = os.getenv("DB_NAME")
DB_USER = os.getenv("DB_USER")
DB_PORT = os.getenv("DB_PORT")

# %%
import database_connect

db = database_connect.DB(DB_HOST, DB_USER, DB_PASSWORD, DB_PORT, DB_NAME)
db.connect()
# Out:
# Connected to the database

# %%
db.buffered_connect()
# Out:
# Connected to the database

# %%
# brew install pkg-config
# brew install mysql-client

# %%
# %pip install sqlalchemy

# %%
interest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1978 entries, 0 to 1977
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1978 non-null   object
#  1   알러지     1978 non-null   int64
#  2   대상포진    1978 non-null   int64
#  3   수족구병    426 non-null    float64
#  4   장염      1978 non-null   int64
#  5   식중독     1827 non-null   float64
#  6   감기      1978 non-null   int64
#  7   인플루엔자   1311 non-null   float64
#  8   동상      1978 non-null   int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 139.2+ KB

# %%
interest_by_region_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1040 non-null   int64
#  1   geoName     1040 non-null   object
#  2   geoCode     1040 non-null   object
#  3   알러지         1040 non-null   int64
#  4   date        1040 non-null   object
#  5   대상포진        1040 non-null   int64
#  6   수족구병        1040 non-null   int64
#  7   장염          1040 non-null   int64
#  8   식중독         1040 non-null   int64
#  9   감기          1040 non-null   int64
#  10  인플루엔자       1040 non-null   int64
#  11  동상          1040 non-null   int64
# dtypes: int64(9), object(3)
# memory usage: 97.6+ KB

# %%
rename_col = {
    "알러지": "allergy",
    "대상포진": "shingles",
    "수족구병": "hfmd",
    "장염": "gastroenteritis",
    "식중독": "food_poisoning",
    "감기": "cold",
    "인플루엔자": "influenza",
    "동상": "frostbite"
}

interest_df.rename(columns=rename_col, inplace=True)
interest_by_region_df.rename(columns=rename_col, inplace=True)

# %%
from sqlalchemy import create_engine

engine = create_engine(f'mysql+mysqldb://{DB_USER}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}')

interest_df.to_sql(name='google_trend_day', con=engine, index=False)
interest_by_region_df.to_sql(name='google_trend_by_region', con=engine, index=False)
# Out:
# 1040

# %%
# dtype으로 인자 조건
from sqlalchemy.types import Integer, String, Float
df.to_sql(
    'my_table',
    engine,
    if_exists='replace',
    index=False,
    dtype={
        'id': Integer,
        'name': String(50),
        'value': Float,
    }
)

# %%
# 테이블 생성 후 ㄱㄱ
from sqlalchemy import create_engine, Column, Integer, String, Float, MetaData, Table
import pandas as pd

# 데이터베이스 연결
engine = create_engine('mysql+pymysql://user:password@localhost/database')

# 테이블 스키마 정의
metadata = MetaData()
my_table = Table(
    'my_table', metadata,
    Column('id', Integer, primary_key=True, autoincrement=True),
    Column('name', String(50), nullable=False),
    Column('value', Float, nullable=True),
)

# 테이블 생성
metadata.create_all(engine)

# 데이터프레임 삽입
df = pd.DataFrame({'name': ['Alice', 'Bob'], 'value': [10.5, 20.3]})
df.to_sql('my_table', engine, if_exists='append', index=False)

# %%
db.select("google_trend", "*")
# Out:
# [('2019-01-01', 0, 0, 0.0, 85, None, 90, 0.0, 76),
#  ('2019-01-02', 0, 54, 0.0, 76, None, 100, 0.0, 0),
#  ('2019-01-03', 77, 52, 0.0, 0, None, 79, 0.0, 79),
#  ('2019-01-04', 0, 43, 0.0, 86, None, 80, 0.0, 0),
#  ('2019-01-05', 0, 66, 0.0, 0, None, 82, 0.0, 0),
#  ('2019-01-06', 0, 0, 0.0, 0, None, 80, 0.0, 0),
#  ('2019-01-07', 100, 57, 0.0, 73, None, 80, 0.0, 0),
#  ('2019-01-08', 0, 68, 0.0, 79, None, 60, 0.0, 0),
#  ('2019-01-09', 82, 0, 0.0, 75, None, 77, 0.0, 0),
#  ('2019-01-10', 0, 0, 0.0, 59, None, 76, 0.0, 0),
#  ('2019-01-11', 83, 55, 0.0, 100, None, 63, 0.0, 100),
#  ('2019-01-12', 0, 49, 0.0, 0, None, 67, 0.0, 67),
#  ('2019-01-13', 0, 66, 0.0, 58, None, 69, 0.0, 0),
#  ('2019-01-14', 0, 43, 0.0, 0, None, 59, 0.0, 0),
#  ('2019-01-15', 0, 46, 0.0, 66, None, 55, 0.0, 0),
#  ('2019-01-16', 0, 0, 0.0, 52, None, 48, 0.0, 0),
#  ('2019-01-17', 0, 53, 100.0, 0, None, 66, 0.0, 0),
#  ('2019-01-18', 0, 45, 0.0, 52, None, 51, 0.0, 0),
# ...

# %%
db.close()

# %%
db.execute("show tables")
db.fetchall()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/data_project_env/lib/python3.10/site-packages/mysql/connector/cursor_cext.py:328, in CMySQLCursor.execute(self, operation, params, multi)
#     327     if not self._connection or self._connection.is_closed():
# --> 328         raise ProgrammingError
#     329 except (ProgrammingError, ReferenceError) as err:
#
# ProgrammingError: Unknown error
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 db.execute("show tables")
#       2 db.fetchall()
#
# File ~/git/eda-repo-4/database_connect.py:44, in DB.execute(self, operation, params, multi)
#      43 def execute(self, operation, params=None, multi=False):
# ...

# %%
db.close()
