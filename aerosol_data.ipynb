# %%
import pandas as pd
import openpyxl

# %%
data_2019_01 = pd.read_excel("/Users/yun/Downloads/2019년 01월.xlsx")
data_2019_01.head(30)
# Out:
#        지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0   서울 중구  도시대기  111121   중구  2019010101  0.003  0.7  0.003  0.054  39.0
# 1   서울 중구  도시대기  111121   중구  2019010102  0.003  0.8  0.002  0.056  38.0
# 2   서울 중구  도시대기  111121   중구  2019010103  0.003  0.9  0.002  0.057  42.0
# 3   서울 중구  도시대기  111121   중구  2019010104  0.003  0.8  0.002  0.054  42.0
# 4   서울 중구  도시대기  111121   중구  2019010105  0.003  0.8  0.002  0.048  49.0
# 5   서울 중구  도시대기  111121   중구  2019010106  0.003  0.8  0.002  0.048  47.0
# 6   서울 중구  도시대기  111121   중구  2019010107  0.003  0.7  0.006  0.040  48.0
# 7   서울 중구  도시대기  111121   중구  2019010108  0.003  0.5  0.014  0.032  33.0
# 8   서울 중구  도시대기  111121   중구  2019010109  0.003  0.8  0.004  0.049  36.0
# 9   서울 중구  도시대기  111121   중구  2019010110  0.003  0.6  0.016  0.031  35.0
# 10  서울 중구  도시대기  111121   중구  2019010111  0.004  0.5  0.031  0.016  34.0
# 11  서울 중구  도시대기  111121   중구  2019010112  0.004  0.5  0.034  0.014  30.0
# 12  서울 중구  도시대기  111121   중구  2019010113  0.004  0.5  0.028  0.020  35.0
# 13  서울 중구  도시대기  111121   중구  2019010114  0.004  0.5  0.031  0.016  40.0
# 14  서울 중구  도시대기  111121   중구  2019010115  0.003  0.4  0.037  0.014  44.0
# 15  서울 중구  도시대기  111121   중구  2019010116  0.003  0.4  0.039  0.013  35.0
# 16  서울 중구  도시대기  111121   중구  2019010117  0.003  0.4  0.036  0.017  35.0
# 17  서울 중구  도시대기  111121   중구  2019010118  0.003  0.4  0.031  0.021  32.0
# 18  서울 중구  도시대기  111121   중구  2019010119  0.004  0.4  0.024  0.027  32.0
# 19  서울 중구  도시대기  111121   중구  2019010120  0.003  0.4  0.022  0.026  31.0
# 20  서울 중구  도시대기  111121   중구  2019010121  0.003  0.4  0.029  0.019  32.0
# 21  서울 중구  도시대기  111121   중구  2019010122  0.003  0.4  0.030  0.017  26.0
# 22  서울 중구  도시대기  111121   중구  2019010123  0.003  0.4  0.031  0.016  25.0
# 23  서울 중구  도시대기  111121   중구  2019010124  0.003  0.4  0.029  0.018  23.0
# 24  서울 중구  도시대기  111121   중구  2019010201  0.004  0.5  0.024  0.023  24.0
# 25  서울 중구  도시대기  111121   중구  2019010202  0.003  0.5  0.023  0.023  24.0
# 26  서울 중구  도시대기  111121   중구  2019010203  0.003  0.5  0.016  0.030  25.0
# 27  서울 중구  도시대기  111121   중구  2019010204  0.003  0.6  0.011  0.033  25.0
# 28  서울 중구  도시대기  111121   중구  2019010205  0.003  0.5  0.012  0.034  26.0
# 29  서울 중구  도시대기  111121   중구  2019010206  0.003  0.5  0.013  0.033  25.0
#
#     PM25             주소
# 0   24.0  서울 중구 덕수궁길 15
# 1   27.0  서울 중구 덕수궁길 15
# 2   28.0  서울 중구 덕수궁길 15
# 3   31.0  서울 중구 덕수궁길 15
# 4   33.0  서울 중구 덕수궁길 15
# 5   32.0  서울 중구 덕수궁길 15
# 6   30.0  서울 중구 덕수궁길 15
# 7   24.0  서울 중구 덕수궁길 15
# 8   22.0  서울 중구 덕수궁길 15
# 9   25.0  서울 중구 덕수궁길 15
# 10  23.0  서울 중구 덕수궁길 15
# 11  22.0  서울 중구 덕수궁길 15
# 12  24.0  서울 중구 덕수궁길 15
# 13  30.0  서울 중구 덕수궁길 15
# 14  30.0  서울 중구 덕수궁길 15
# 15  25.0  서울 중구 덕수궁길 15
# 16  25.0  서울 중구 덕수궁길 15
# 17  23.0  서울 중구 덕수궁길 15
# 18  21.0  서울 중구 덕수궁길 15
# 19  21.0  서울 중구 덕수궁길 15
# 20  20.0  서울 중구 덕수궁길 15
# 21  16.0  서울 중구 덕수궁길 15
# 22  17.0  서울 중구 덕수궁길 15
# 23  16.0  서울 중구 덕수궁길 15
# 24  15.0  서울 중구 덕수궁길 15
# 25  17.0  서울 중구 덕수궁길 15
# 26  17.0  서울 중구 덕수궁길 15
# 27  18.0  서울 중구 덕수궁길 15
# 28  19.0  서울 중구 덕수궁길 15
# 29  17.0  서울 중구 덕수궁길 15

# %%
data_2019_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306456 entries, 0 to 306455
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   측정일시    306456 non-null  int64
#  1   지역      306456 non-null  object
#  2   망       306456 non-null  object
#  3   측정소코드   306456 non-null  int64
#  4   측정소명    306456 non-null  object
#  5   주소      306456 non-null  object
#  6   SO2     292630 non-null  float64
#  7   CO      292339 non-null  float64
#  8   O3      295313 non-null  float64
#  9   NO2     296881 non-null  float64
#  10  PM10    295934 non-null  float64
#  11  PM25    284688 non-null  float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 28.1+ MB

# %%
new_order = ['측정일시', '지역', '망', '측정소코드', '측정소명', '주소', 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25']

data_2019_01 = data_2019_01[new_order]
data_2019_01.head()
# Out:
#          측정일시     지역     망   측정소코드 측정소명             주소    SO2   CO     O3  \
# 0  2019010101  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.003  0.7  0.003
# 1  2019010102  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.003  0.8  0.002
# 2  2019010103  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.003  0.9  0.002
# 3  2019010104  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.003  0.8  0.002
# 4  2019010105  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.003  0.8  0.002
#
#      NO2  PM10  PM25
# 0  0.054  39.0  24.0
# 1  0.056  38.0  27.0
# 2  0.057  42.0  28.0
# 3  0.054  42.0  31.0
# 4  0.048  49.0  33.0

# %%
new_order = ['측정일', '지역', '망', '측정소코드', '측정소명', '주소', 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25']

# SO2, CO, O3, NO2, PM10, PM25만 평균값 계산
columns_to_aggregate = ['SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25']
df_aggregated = data_2019_01[columns_to_aggregate].groupby(data_2019_01.index // 24).mean().reset_index(drop=True)

# 나머지 열들은 첫 번째 값을 그대로 가져오기
df_aggregated['지역'] = data_2019_01.groupby(data_2019_01.index // 24)['지역'].first().reset_index(drop=True)
df_aggregated['망'] = data_2019_01.groupby(data_2019_01.index // 24)['망'].first().reset_index(drop=True)
df_aggregated['측정소코드'] = data_2019_01.groupby(data_2019_01.index // 24)['측정소코드'].first().reset_index(drop=True)
df_aggregated['측정소명'] = data_2019_01.groupby(data_2019_01.index // 24)['측정소명'].first().reset_index(drop=True)
df_aggregated['주소'] = data_2019_01.groupby(data_2019_01.index // 24)['주소'].first().reset_index(drop=True)

# '측정일시'는 첫 번째 값만 남기기
df_aggregated['측정일'] = data_2019_01.groupby(data_2019_01.index // 24)['측정일시'].first().astype(str).str[:-2].reset_index(drop=True)
df_aggregated = df_aggregated[new_order]

df_aggregated.head()
# Out:
#         측정일     지역     망   측정소코드 측정소명             주소       SO2        CO  \
# 0  20190101  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.003208  0.558333
# 1  20190102  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.003625  0.562500
# 2  20190103  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.003833  0.662500
# 3  20190104  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.005667  1.029167
# 4  20190105  서울 중구  도시대기  111121   중구  서울 중구 덕수궁길 15  0.004667  0.633333
#
#          O3       NO2       PM10       PM25
# 0  0.020208  0.030125  35.958333  24.541667
# 1  0.015125  0.035958  33.041667  22.208333
# 2  0.007042  0.047833  35.250000  21.791667
# 3  0.002708  0.067875  54.708333  37.916667
# 4  0.020583  0.029958  60.041667  38.041667
